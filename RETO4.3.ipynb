# %% [markdown]
# #Desea determinar si un carácter 'x' es un dígito o no.

# %%
x = (input("ingrese un carácter:"))
if '0' <= x <= '9':
   print("El carácter " + str(x) + " es un dígito")
else:
    print("El carácter seleccionado no es un dígito")
# Out:
# ingrese un carácter:a
# El carácter seleccionado no es un dígito
