# %% [markdown]
# #Identificador de numeros positivos, negativos y neutro para la suma.

# %%
n: float
n = float(input("ingrese un número real : "))
if n == 0:
  print("El numero" + str(n)+ "es el neutro para la suma")
else:
  if n < 0:
    print("El numero" + str(n) + " es negativo")
  if n > 0:
    print("El numero" + str(n) + " es positivo")
# Out:
# ingrese un número real : 5
# El numero5.0 es positivo
